# %%
import pandas as pd
from pathlib import Path

DATA_DIR = Path("../data")

def load_data():
    df = pd.read_excel(DATA_DIR / "raw" / "uso_del_suelo.xlsx", sheet_name="Cuadro 4.")
    return df

df = load_data()

df.head()
