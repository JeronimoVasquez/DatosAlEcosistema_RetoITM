# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Leer datos
df_dpto = pd.read_csv("..\\data\\processed\\suelo_forestal_depto.csv")

# %%
departamentos = df_dpto["depto"].unique()
departamentos
# Out:
# array(['antioquia', 'boyacá', 'caldas', 'cundinamarca', 'huila',
#        'norte de santander', 'quindio', 'risaralda', 'santander',
#        'tolima', 'atlantico', 'san andres', 'bolivar', 'cesar', 'cordoba',
#        'la guajira', 'magdalena', 'sucre', 'cauca', 'choco', 'nariño',
#        'valle del cauca', 'arauca', 'casanare', 'meta', 'vichada',
#        'amazonas', 'caqueta', 'guainia', 'guaviare', 'putumayo', 'vaupes'],
#       dtype=object)

# %%
df_dpto['Fecha'] = pd.to_datetime(df['ano'], format='%Y')
df_dpto = df_dpto.sort_values(['depto', 'Fecha'])

# %%
for depto, subset in df_dpto.groupby('depto'):
    plt.figure(figsize=(8, 4))
    
    plt.plot(subset['Fecha'], subset['total'], marker='o')
    
    plt.title(f"Serie de tiempo - {depto}")
    plt.xlabel("Año")
    plt.ylabel("Total")
    plt.grid(True)
    
    plt.show()

# %%
df_region = pd.read_csv("..\\data\\processed\\suelo_forestal_region.csv")

# %%
df_region['Fecha'] = pd.to_datetime(df_region['ano'], format='%Y')
df = df_region.sort_values(['region', 'Fecha'])

# %%
for region, subset in df_region.groupby('region'):
    plt.figure(figsize=(8, 4))
    
    plt.plot(subset['Fecha'], subset['total'], marker='o')
    
    plt.title(f"Serie de tiempo - {region}")
    plt.xlabel("Año")
    plt.ylabel("Total")
    plt.grid(True)
    
    plt.show()
